# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv("wine.csv")
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
x = df['Alcohol'].values.reshape(-1, 1) # 1 Independent
y = df['Wine'] # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 5.756420154501262
# Coefficients: [-0.29213397]
# Mean Squared Error: 0.5072695876025006
# R-squared: 0.1303949926814273
# Predicted Price for new house: 1.5993538292680753

# %%
x = df[['Alcohol','Malic.acid']] # 2 Indepndent
y = df['Wine']  # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 5.316540112768429
# Coefficients: [-0.31724322  0.32263253]
# Mean Squared Error: 0.3859907549299584
# R-squared: 0.33830156297721403
# Predicted Price for new house: 1.4313025884746646
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[['Alcohol','Malic.acid','Ash']]  # 3  Independent
y = df['Wine']  # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95,2.43]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 5.566659114000653
# Coefficients: [-0.3048372   0.33069406 -0.18225334]
# Mean Squared Error: 0.38835191725180407
# R-squared: 0.3342538561397643
# Predicted Price for new house: 1.4308035110981132
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[['Alcohol','Malic.acid','Ash','Acl']]  # 4 Independent
y = df['Wine']  # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95,2.43,15.6]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 2.277989203941475
# Coefficients: [-0.07761495  0.24578275 -0.96184033  0.12229891]
# Mean Squared Error: 0.34309584432131
# R-squared: 0.41183569544918275
# Predicted Price for new house: 1.223395839602586
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[['Alcohol','Malic.acid','Ash','Acl','Mg']]  # 5 Independent
y = df['Wine']  # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95,2.43,15.6,127]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 2.319289023105319
# Coefficients: [-7.64217663e-02  2.44562866e-01 -9.49270917e-01  1.21708423e-01
#  -7.17482365e-04]
# Mean Squared Error: 0.34200327232046823
# R-squared: 0.4137086760220543
# Predicted Price for new house: 1.2095076887605287
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[['Alcohol','Malic.acid','Ash','Acl','Mg','Phenols']]  # 6 Independent
y = df['Wine']   # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95,2.43,15.6,127,2.8]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 2.715707376479944
# Coefficients: [-1.79947989e-02  1.54709037e-01 -5.96188572e-01  9.09630984e-02
#   4.84597209e-04 -5.66636948e-01]
# Mean Squared Error: 0.19431827404159296
# R-squared: 0.6668829587858406
# Predicted Price for new house: 1.2065705072332245
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x = df[['Alcohol','Malic.acid','Ash','Acl','Mg','Phenols','Flavanoids','Nonflavanoid.phenols','Proanth','Color.int','Hue','OD','Proline']]   #  13 Independent
y = df['Wine']  # Dependent
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()
 
# Train the model
model.fit(x_train, y_train)
 
# Make predictions on the test set
y_pred = model.predict(x_test)
 
# Coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
 
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
 
print("Mean Squared Error:", mse)

print("R-squared:", r2)
 
 
new_house = np.array([[14.23,1.95,2.43,15.6,127,2.8,3.06,0.28,2.29,5.64,1.04,3.92,1065]])

predicted_price = model.predict(new_house)

print(f"Predicted Price for new house: {predicted_price[0]}")
# Out:
# Intercept: 4.292824701981549
# Coefficients: [-1.09279520e-01  4.33504334e-02 -2.04972602e-01  4.40282611e-02
#   3.77391056e-05  1.52212162e-01 -3.53372029e-01 -3.20200804e-01
#   1.75960551e-02  7.68233961e-02 -9.13449280e-02 -2.81542501e-01
#  -6.97267143e-04]
# Mean Squared Error: 0.06853348464256041
# R-squared: 0.8825140263270392
# Predicted Price for new house: 0.8034242931941318
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
